# %%
import examen as ex

# %%
ola= ex.cargar_data("listings5.csv")
ola
# Out:
#                        id                                       listing_url  \
# 0                   75065                https://www.airbnb.com/rooms/75065
# 1                  145013               https://www.airbnb.com/rooms/145013
# 2                  261800               https://www.airbnb.com/rooms/261800
# 3                  872640               https://www.airbnb.com/rooms/872640
# 4                 1199731              https://www.airbnb.com/rooms/1199731
# ...                   ...                                               ...
# 4020  1318078714426232647  https://www.airbnb.com/rooms/1318078714426232647
# 4021  1318372398406695359  https://www.airbnb.com/rooms/1318372398406695359
# 4022  1318787396928973862  https://www.airbnb.com/rooms/1318787396928973862
# 4023  1320443462789358388  https://www.airbnb.com/rooms/1320443462789358388
# 4024  1321096680919768887  https://www.airbnb.com/rooms/1321096680919768887
#
#            scrape_id last_scraped           source  \
# ...

# %%
cuenta_nulos= ex.cuenta_nulos(ola)
cuenta_nulos
# Out:
# ('Valores nulos por columna',
#  id                                                 0
#  listing_url                                        0
#  scrape_id                                          0
#  last_scraped                                       0
#  source                                             0
#  name                                               0
#  description                                       46
#  neighborhood_overview                           2242
#  picture_url                                        0
#  host_id                                            0
#  host_url                                           0
#  host_name                                          0
#  host_since                                         0
#  host_location                                   1121
#  host_about                                      2377
#  host_response_time                               960
#  host_response_rate                               960
# ...

# %%
sin_nulos= ex.nulos_general(ola)

# %%
cuenta33=ex.cuenta_nulos(sin_nulos)
cuenta33
# Out:
# ('Valores nulos por columna',
#  listing_url                                        0
#  last_scraped                                       0
#  source                                             0
#  name                                               0
#  description                                        0
#  neighborhood_overview                              0
#  picture_url                                        0
#  host_url                                           0
#  host_name                                          0
#  host_since                                         0
#  host_location                                      0
#  host_about                                         0
#  host_response_time                                 0
#  host_response_rate                                 0
#  host_acceptance_rate                               0
#  host_is_superhost                                  0
#  host_thumbnail_url                                 0
# ...

# %%
olaola= ex.sus_intercuartilico(sin_nulos)

# %%
olaola.to_csv("listings5_LIMPIO.csv")
